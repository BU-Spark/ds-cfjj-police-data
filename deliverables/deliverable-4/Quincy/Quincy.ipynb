# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("FIO.csv")

df.head()
# Out:
#     Sex   Age   Race               Ethnicity        Location       Date/Time  \
# 0  MALE  36.0  WHITE  NOT OF HISPANIC ORIGIN  101 FALLS BLVD  11/18/18 16:18
# 1  MALE  52.0  WHITE  NOT OF HISPANIC ORIGIN  101 FALLS BLVD  11/18/18 16:18
# 2  MALE  40.0  WHITE  NOT OF HISPANIC ORIGIN      0 LARRY ST    9/5/18 13:11
# 3   NaN  47.0    NaN                     NaN   100 QUINCY AV  10/27/18 18:25
# 4  MALE  62.0  WHITE  NOT OF HISPANIC ORIGIN  475 HANCOCK ST   9/16/18 18:36
#
#   Source Search  Outcome          Officer   Badge  Other Officer  Other Badge
# 0    NaN    NaN      NaN  GOLDRICK, JAMES  7157.0            NaN          NaN
# 1    NaN    NaN      NaN  GOLDRICK, JAMES  7157.0            NaN          NaN
# 2    NaN    NaN      NaN               ,      NaN            NaN          NaN
# 3    NaN    NaN      NaN               ,      NaN            NaN          NaN
# 4    NaN    NaN      NaN               ,      NaN            NaN          NaN

# %%
total_race = df.groupby(['Race']).size()
fig = plt.figure()

plt.bar(total_race.index, total_race.values)
plt.xlabel=('Races')
plt.ylabel=('Total FIOs Reported')
plt.title('FIOs by Race')
plt.show()

# %%
total_ethnic = df.groupby(['Ethnicity']).size()
fig = plt.figure()

plt.bar(total_ethnic.index, total_ethnic.values)
plt.xlabel=('Races')
plt.ylabel=('Total FIOs Reported')
plt.title('FIOs by Ethnicity')
plt.show()

# %%
total_age = df.groupby(['Age']).size()
fig = plt.figure()

plt.bar(total_age.index, total_age.values)
plt.xlabel=('Races')
plt.ylabel=('Total FIOs Reported')
plt.title('FIOs by Age')
plt.show()

# %%
total_sex = df.groupby(['Sex']).size()
fig = plt.figure()

plt.bar(total_sex.index, total_sex.values)
plt.xlabel=('Races')
plt.ylabel=('Total FIOs Reported')
plt.title('FIOs by Sex')
plt.show()
