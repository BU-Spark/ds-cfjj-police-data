# %%
# !pip3 install tabula-py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 12.0 MB 14.9 MB/s eta 0:00:01
# ...
#   WARNING: The script distro is installed in '/Users/faridkar/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import tabula
